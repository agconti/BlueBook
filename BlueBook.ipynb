# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy import *
from pandas import Series,DataFrame
from patsy import dmatrices
cd 'C:\Users\Andrew\Documents\Kaggle\Blue Book For Bulldozers\Dups/'
plt.figure(figsize=(12,8))

# %%
import sys
sys.path.append('C:\Users\Andrew\Documents\Kaggle\Kaggel Aux')
import kaggelaux as agc

# %%
df=pd.read_csv("trainapp2.csv") # Import Data
df=df.ix[:,'MachineID':'state'] # Remove extraneous Features

# %%
# Below are several helpful functions that we will use to clean the data and prepare it for our analysis. 
def machine_indexbool(s):
    if s == False:
        s = np.nan
    return s

def dozeryearclean(s):
    year_prox = test_data.YearMade[test_data.YearMade != 1000].mean()
    if s == 1000:
        s = year_prox
    return s

def dozeryearcleandf(s):
    year_prox = df.YearMade[df.YearMade != 1000].mean()
    if s == 1000:
        s =year_prox
    return s

def MfgClean(s):
    if isinstance(s, str):
        s = np.nan
    return s

# %%
# Prepares data for analysis
df.saledate = df.saledate.apply(lambda x: datetime.datetime.strptime(str(x), '%m/%d/%Y %H:%M'))
df = df.dropna()

# %%
df['Quater'] = df.saledate.apply(agc.quater_maker)
df.Quater.head()
# Out:
# 307     Q4
# 401     Q1
# 758     Q4
# 772     Q4
# 1312    Q1
# Name: Quater, dtype: object

# %% [markdown]
# # Visual Summary of the Data:

# %%
fig = plt.figure(figsize=(20,10))
df['Log_SalePrice'] = df.SalePrice.apply(lambda x: log(x)) # transforms sales price
a=.65 # sets the alpha level

fig.add_subplot(2,3,1)
df.SalePrice.plot(kind='kde')
title("Distribution of Sales"); legend(loc='best')

fig.add_subplot(2,3,2)
df.Log_SalePrice.plot(kind='kde')
title("Logged Distribution of Sales"); legend(loc='best')

#ax=plt.subplot2grid((2, 3), (1, 3), rowspan=2)
fig.add_subplot(2,3,5)
df.YearMade.value_counts().plot(kind='barh', alpha=a)
title("When were these bulldozers made?")
# you could show a distrubution of how old they are

fig.add_subplot(2,3,4)
df.Quater.value_counts().plot(kind='bar',alpha= a)
title("Distribution of Bulldozer Sales by Quater")

fig.add_subplot(2,3,3)
df.SalePrice.plot(df.saledate)
title("Sale Price Over Time:")
plt.xlabel('MachineID')
plt.ylabel('Price ($)')
#plt.xticks(np.arange(0,5))
#plt.yticks(np.arange(0,5))

fig.add_subplot(2,3,6)
df.UsageBand.value_counts().plot(kind='bar', alpha=a)
title("Distribution of Hours the Dozers were used. ")

# %% [markdown]
# # Data Quality? What are we up against?

# %% [markdown]
# briefly explain data quality issues machine index and how they were handeled

# %% [markdown]
# # My Regressions:

# %% [markdown]
# #### Regression 1:

# %% [markdown]
# show a typicall competitor reg  with  GDP without my adds. show reg with my adds. show how you zeroed in to things that made sense to explain the dozers and how r2 went up. expalin the seasonalitly/ inflation in the dataset show how you adj. then show output to kaggel. Explain why everything is lagged 90 days

# %%
df.set_index("SalesID")
# So our regression Data frames objs keep thier salesid

# %%
df.columns
# Out:
# Index([MachineID, ModelID, inflate, inflate90, cat_price, cat_price_l1, cat_price_l30, cat_price_l90, fred_diff3, freda, fredb, freda90, fredb90, fiModelDesc, fiBaseModel, fiSecondaryDesc, fiModelSeries, fiModelDescriptor, fiProductClassDesc, ProductGroup, ProductGroupDesc, MfgYear, fiManufacturerID, fiManufacturerDesc, PrimarySizeBasis, PrimaryLower, PrimaryUpper, SalesID, SalePrice, datasource, auctioneerID, YearMade, MachineHoursCurrentMeter, UsageBand, saledate, ProductSize, state, Quater, Log_SalePrice], dtype=object)

# %%
y, x = dmatrices('SalePrice ~ C(UsageBand)', data=df, return_type='dataframe')# Prepare data frame for regression
mod = sm.OLS(y, x)   # Describe model, so it can be fitted mod = sm.GLM(y, x, family=sm.families.Gamma()) 
res1 = mod.fit()       # Fit model
print res1.summary()   # Summarize model -- you dont have to print
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     40.64
# Date:                Sat, 20 Apr 2013   Prob (F-statistic):           6.24e-18
# Time:                        14:31:57   Log-Likelihood:                -18229.
# No. Observations:                1564   AIC:                         3.646e+04
# Df Residuals:                    1561   BIC:                         3.648e+04
# Df Model:                           2
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Intercept               6.831e+04   1286.955     53.080      0.000      6.58e+04  7.08e+04
# C(UsageBand)[T.Low]    -1.962e+04   2177.070     -9.011      0.000     -2.39e+04 -1.53e+04
# C(UsageBand)[T.Medium] -7244.6961   1607.774     -4.506      0.000     -1.04e+04 -4091.071
# ==============================================================================
# Omnibus:                       93.465   Durbin-Watson:                   1.552
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.744
# Skew:                           0.322   Prob(JB):                     7.86e-13
# Kurtosis:                       2.337   Cond. No.                         4.28
# ==============================================================================

# %% [markdown]
# #### Regression 2:

# %%
formula2 = 'np.log(SalePrice) ~ inflate90 + fredb90 + np.log(cat_price_l90) + C(YearMade) + C(ModelID) + C(Quater) + C(auctioneerID) + C(UsageBand)'

# %%
formula2 = 'SalePrice ~ inflate90 + fredb90 + np.log(cat_price_l90) + C(YearMade) + C(ModelID) + C(Quater) + C(auctioneerID) + C(UsageBand)'

# %%
y, x = dmatrices(formula2, data=df, return_type='dataframe')
mod = sm.GLM(y, x)   # Describe model, so it can be fitted C(UsageBand)
res2 = mod.fit()     # Fit model
print res2.summary() # Summarize model
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1564
# Model:                            GLM   Df Residuals:                     1471
# Model Family:                Gaussian   Df Model:                           92
# Link Function:               identity   Scale:                   181342528.077
# Method:                          IRLS   Log-Likelihood:                -17042.
# Date:                Sat, 20 Apr 2013   Deviance:                   2.6675e+11
# Time:                        15:46:51   Pearson chi2:                 2.67e+11
# No. Iterations:                     3
# ==================================================================================================================================================
#                                                                                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                      -1.314e+05   8644.563    -15.196      0.000     -1.48e+05 -1.14e+05
# fiBaseModel[T.1850]                                                             -762.2611   7352.995     -0.104      0.917     -1.52e+04  1.36e+04
# fiBaseModel[T.345]                                                              2.024e+04   9364.969      2.161      0.031      1884.855  3.86e+04
# fiBaseModel[T.430]                                                             -3.328e+04   7895.305     -4.216      0.000     -4.88e+04 -1.78e+04
# fiBaseModel[T.570]                                                             -1.359e+04   1356.655    -10.018      0.000     -1.62e+04 -1.09e+04
# fiBaseModel[T.750]                                                             -2658.1062   3365.540     -0.790      0.430     -9254.443  3938.231
# C(auctioneerID)[T.7.0]                                                         -1672.7597   4181.773     -0.400      0.689     -9868.885  6523.366
# C(auctioneerID)[T.8.0]                                                         -2151.6714   4572.907     -0.471      0.638     -1.11e+04  6811.063
# C(auctioneerID)[T.9.0]                                                          2.368e+04   1.45e+04      1.630      0.103     -4790.527  5.22e+04
# C(auctioneerID)[T.10.0]                                                         1.263e+04   6870.556      1.839      0.066      -832.337  2.61e+04
# C(auctioneerID)[T.11.0]                                                         1.042e+04   1.37e+04      0.761      0.447     -1.64e+04  3.72e+04
# C(auctioneerID)[T.12.0]                                                         4819.0479   7904.053      0.610      0.542     -1.07e+04  2.03e+04
# C(auctioneerID)[T.13.0]                                                         -843.5808   3726.663     -0.226      0.821     -8147.707  6460.545
# C(auctioneerID)[T.16.0]                                                         5770.6915   5636.629      1.024      0.306     -5276.898  1.68e+04
# C(auctioneerID)[T.20.0]                                                         2286.5554   3884.629      0.589      0.556     -5327.177  9900.288
# C(auctioneerID)[T.21.0]                                                        -7304.7425   9742.859     -0.750      0.454     -2.64e+04  1.18e+04
# C(auctioneerID)[T.22.0]                                                         -2.34e+04   1.39e+04     -1.679      0.093     -5.07e+04  3909.051
# C(auctioneerID)[T.24.0]                                                         5354.8913   6735.067      0.795      0.427     -7845.597  1.86e+04
# C(auctioneerID)[T.26.0]                                                         3.389e+04   9699.222      3.494      0.000      1.49e+04  5.29e+04
# C(auctioneerID)[T.27.0]                                                         -911.0228    1.4e+04     -0.065      0.948     -2.83e+04  2.65e+04
# C(auctioneerID)[T.28.0]                                                        -2.418e+04   1.45e+04     -1.664      0.096     -5.26e+04  4292.484
# C(auctioneerID)[T.99.0]                                                        -1417.5877   2106.881     -0.673      0.501     -5546.998  2711.822
# C(UsageBand)[T.Low]                                                             9508.8595   1282.357      7.415      0.000      6995.486   1.2e+04
# C(UsageBand)[T.Medium]                                                          4571.5039    849.304      5.383      0.000      2906.898  6236.110
# fredb                                                                           2119.6926    126.994     16.691      0.000      1870.789  2368.596
# np.log(cat_price_l90)                                                          -8786.7801   1244.206     -7.062      0.000     -1.12e+04 -6348.180
# ==================================================================================================================================================

# %% [markdown]
# #### Regresion 3:

# %%
formula2='np.log(SalePrice) ~ fiBaseModel + C(fiProductClassDesc) + fredb + np.log(cat_price_l90) + C(YearMade) + C(Quater) + C(auctioneerID) + C(UsageBand)'

# %%
y, x = dmatrices(formula2, data= df, return_type='dataframe')
mod = sm.OLS(y, x)    # Describe model, so it can be fitted  fredb
res3 = mod.fit()       # Fit model
res3.summary()   # Summarize model -- you dont have to print
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(SalePrice)   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                     84.17
# Date:                Sat, 20 Apr 2013   Prob (F-statistic):               0.00
# Time:                        15:43:47   Log-Likelihood:                 54.002
# No. Observations:                1564   AIC:                             78.00
# Df Residuals:                    1471   BIC:                             576.0
# Df Model:                          92
# ==================================================================================================================================================
#                                                                                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                
# C(auctioneerID)[T.21.0]                                                           -0.1039      0.174     -0.596      0.551        -0.446     0.238
# C(auctioneerID)[T.22.0]                                                           -0.3303      0.249     -1.325      0.186        -0.819     0.159
# C(auctioneerID)[T.24.0]                                                            0.3170      0.121      2.630      0.009         0.081     0.553
# C(auctioneerID)[T.26.0]                                                            0.6110      0.174      3.520      0.000         0.270     0.952
# C(auctioneerID)[T.27.0]                                                           -0.0234      0.250     -0.094      0.925        -0.514     0.468
# C(auctioneerID)[T.28.0]                                                           -0.3496      0.260     -1.345      0.179        -0.860     0.160
# C(auctioneerID)[T.99.0]                                                           -0.0301      0.038     -0.799      0.425        -0.104     0.044
# C(UsageBand)[T.Low]                                                                0.1527      0.023      6.652      0.000         0.108     0.198
# C(UsageBand)[T.Medium]                                                             0.0613      0.015      4.030      0.000         0.031     0.091
# fredb                                                                              0.0354      0.002     15.555      0.000         0.031     0.040
# np.log(cat_price_l90)                                                             -0.1519      0.022     -6.820      0.000        -0.196    -0.108
# ==============================================================================
# Omnibus:                      188.899   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1295.201
# Skew:                          -0.327   Prob(JB):                    5.63e-282
# Kurtosis:                       7.410   Cond. No.                          nan
# ==============================================================================
#
# The smallest eigenvalue is -6.65e-14. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Use Our Models to Make Predictions:

# %% [markdown]
# #makes predictions
# df_r1=agc.regress_pred_output(pd.read_csv(PATH+'Validappend.csv'),res1, 'SalePrice')
# df_r2=agc.regress_pred_output(pd.read_csv(PATH+'Validappend.csv'),res2,'SalePrice')
# df_r3=agc.regress_pred_output(pd.read_csv(PATH+'Validappend.csv'),res3,'SalePrice')
#
# #saves output
# df_r1.to_csv(PATH+'regres1.csv')
# df_r2.to_csv(PATH+'regres2.csv')
# df_r3.to_csv(PATH+'regres3.csv')

# %%
pew+1=4/pew_pew

# %%
test_data = pd.read_csv("Testwadds.csv")

# %%
# Clean data in same way as our training data
test_data.saledate = test_data.saledate.apply(lambda x: datetime.datetime.strptime(str(x), '%m/%d/%Y %H:%M')) 
test_data['Quater'] = test_data.saledate.apply(ka.quater_maker)
test_data['SalePrice'] = 1.23
test_data = test_data.set_index("SalesID")

# %%
results = res3.params

#Create reg friendly test dataframe
yt, xt = dmatrices(formula2, data= test_data, return_type='dataframe')

z = Series(results)
zd = z.to_dict()

error_l = 0
yholder = 0
for i in xt.index:
    for w in xt.columns:
        if w in zd:
            yholder += xt.ix[i,w]*zd[w]
        else:
            error_l += 1
    yt.ix[i] = yholder
    yholder = 0
print error_l
# Out:
# 11099187

# %%
yt['SalePrice'] = yt['np.log(SalePrice)'].apply(lambda x: exp(x))

# %%
yt.to_csv(PATH+"GLMTestres7.csv", na_rep=0, float_format='%.3f')

# %%
show score and finnal postion on the leader board, talk about good model for overall prediction but poor for specific concentrated test set. expalin the winners soultion

# %%
valsol=pd.read_csv('ValidSolution.csv')
early=pd.read_csv('OLSExtend001.csv')

# %%
test_data.YearMade.value_counts()

# %%
float(1637)/float(test_data.YearMade.size)

# %%
agc.score_rmsle('SalePrice',xt,valsol)

# %%
agc.score_rmse('SalePrice',xt,valsol)

# %%
show winners final place
show random forest soultion and that final place
