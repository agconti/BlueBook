# %% [markdown]
# ##Kaggle Competition | Blue Book for Bulldozers
# Below is a IPython Notebook that contains a quantitative pricing model for a growing startup, _FastIron_, to predict the sale price of a particular piece of heavy equipment at auction based on its usage, equipment type, and configuration. Here I use python as a medium to apply supervised and unsupervised machine learning techniques to achieve an R2 of 0.877. Finished the competition in the top 20% out of 590 participants.
#
# By Andrew Conti

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy import *
from pandas import Series,DataFrame
from patsy import dmatrices, incr_dbuilder
plt.figure(figsize=(12,8))
results={}

# %%
# Sets our path
#cd "C:\\Users\\Andrew\\Documents\\Kaggle\\Blue Book For Bulldozers/Dups/BlueBook git/"

# %%
import sys
sys.path.append('C:\Users\Andrew\Documents\Kaggle\Kaggel Aux')
import kaggelaux as agc

# %%
df = pd.read_csv("Train.csv") # Import Data
df = df.ix[:,'SalesID':'ProductGroupDesc'] # Remove extraneous Features

# %% [markdown]
# # Data Quality? What are we up against?

# %% [markdown]
# Like most real world data, there were many inaccuracies and occurrences of malformed data in the dataset provided by FastIron.
# <br />
# <br />
# **_Some of the Highlights include:_**
# <ul>
#     <li>Many Bulldozers were reported as being manufactured in 1000 A.D.</li>
#     <li> Many Bulldozers had multiple manufacturing dates.</li>
#     <li> Machine ID, that was supposed to track an individual machine over its lifetime, was assigned to many machines.</li>
#     <li> Auctioneer ID was later revealed as an aggregate of of binned auction houses created by FastIorn, instead of individual auction houses</li>
# </ul>
# <br />
# <br />
# To compensate for these errors FastIron released an appendix to correct the data, though many believed the appendix had many of the same problems.
# These issues are compensated for in below.

# %% [markdown]
# #Auxilary Data:
# In Addition to the information provided by FastIorn, I included several features to account for seasonality, inflation, and the changing demand of heavy machinery.
# <br />
# <br />
# **Those Features are:**
# <br />
#
# <ul>
#  <li>GDP -- FRED </li>
#  <li>US Inflation -- FRED</li>
#  <li>US Heavy Industrial Production Index - FRED</li>
#  <li>Caterpillar’s adjusted closing price -- Yahoo Finance</li>
# </ul>
# <br />
# ***All added features were lagged 90 days so that they would be available at the auction time***
# <br />
# <br />
# Below shows process of lagging and merging the new data as well as the new Machine Appendix to fix data quality issues.

# %% [markdown]
# ### Read in additional data:

# %%
machine_appendix = pd.read_csv('Machine_Appendix.csv')
GDP = pd.read_csv('GDP.csv', names=['DATE','GDP'], header=0)
inflation = pd.read_csv('CPIAUCSL.csv',names=['DATE','Infation_Index'], header=0)
Industrial_production = pd.read_csv('INDPRO_vb.csv',names=['DATE','Industrial_production_index'], header=0)
cat = pd.read_csv('cat_data.csv',names=['Date','cat_open','cat_high','cat_low','cat_close','cat_vol','cat_adj_close'], header=0)

# %% [markdown]
# ### Prepare data for merge and comparison:

# %%
# New data
GDP.DATE = GDP.DATE.apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d")) # Coverts string dates into datetime objects
inflation.DATE = inflation.DATE.apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d"))
Industrial_production.DATE = Industrial_production.DATE.apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d"))
cat.Date = cat.Date.apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))
# Our original data
df.saledate = df.saledate.apply(lambda x: datetime.datetime.strptime(str(x), '%m/%d/%Y %H:%M'))

# %% [markdown]
# ### Merge data on the machine appendix to correct for data quality .

# %%
df = pd.merge(df, machine_appendix, left_on='MachineID', right_on='MachineID', how='right', suffixes=('_orginal','_machine_appendix'))

# %% [markdown]
# ### Fill data forward to make a complete calender; ie. not just trading/business days as auctions happend 24/7.

# %%
# Prepare data for forward filling
GDP = GDP.set_index('DATE')
inflation = inflation.set_index('DATE')
Industrial_production = Industrial_production.set_index('DATE')
cat = cat.set_index('Date')

# Fill data forward
GDP = GDP.resample('D', fill_method='ffill')
inflation = inflation.resample('D', fill_method='ffill')
Industrial_production = Industrial_production.resample('D', fill_method='ffill')
cat = cat.resample('D', fill_method='ffill')

# %% [markdown]
# ### Lag our new variales and then merge them to our dataset:

# %%
df = pd.merge(GDP.shift(90, freq='D'), df, left_index=True, right_on='saledate', how='right')
df = pd.merge(inflation.shift(90, freq='D'), df, left_index=True, right_on='saledate', how='right')
df = pd.merge(Industrial_production.shift(90, freq='D'), df, left_index=True, right_on='saledate', how='right')
df = pd.merge(cat.shift(90, freq='D'), df, left_index=True, right_on='saledate', how='right')

# %% [markdown]
# ### Below are several helpful functions that we will use to clean the dozer manufacturing date data and prepare it for our analysis.

# %%
def dozeryearclean(s):
    if s == 1000:
        s = np.nan
    return s

def MfgClean(s):
    if isinstance(s, str):
        s = np.nan
    return s

# %% [markdown]
# ###Lets take a look at our new dataframe. Below is a summary of the data frame, its observations and its features:

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418691 entries, 0 to 418690
# Data columns (total 44 columns):
# cat_open                               401125  non-null values
# cat_high                               401125  non-null values
# cat_low                                401125  non-null values
# cat_close                              401125  non-null values
# cat_vol                                401125  non-null values
# cat_adj_close                          401125  non-null values
# Industrial_production_index            401125  non-null values
# Infation_Index                         401125  non-null values
# GDP                                    401125  non-null values
# SalesID                                401125  non-null values
# SalePrice                              401125  non-null values
# MachineID                              418691  non-null values
# ModelID_orginal                        401125  non-null values
# ...

# %% [markdown]
# ### Clean Data to prepare for analysis:

# %%
df.YearMade = df.YearMade.apply(dozeryearclean)
df.MfgYear = df.MfgYear.apply(MfgClean)
df['Quater'] = df.saledate.apply(agc.quater_maker)# adds a column for that specifices the quater each machine was sold in.

df = df.dropna() # Drops Null Values from the dataframe.

# %% [markdown]
# # Visual Summary of the Data:

# %%
fig = plt.figure(figsize=(14,6))
df['Log_SalePrice'] = df.SalePrice.apply(lambda x: log(x)) # transforms sales price
a=.65 # sets the alpha level

ax1 = plt.subplot2grid((2, 3), (0, 1))
df.SalePrice.plot(kind='kde')
title("Distribution of Sales"); legend(loc='best')

ax2 = plt.subplot2grid((2, 3), (0, 2), colspan=2)
df.Log_SalePrice.plot(kind='kde')
title("Logged Distribution of Sales"); legend(loc='best')

ax3 = plt.subplot2grid((2, 3), (0, 0), colspan=1, rowspan=2)
df.YearMade.value_counts().plot(kind='barh', alpha=a)
title("When were these bulldozers made?")
plt.xlabel('Count')
plt.ylabel('Year')
# you could show a distrubution of how old they are

ax4 = plt.subplot2grid((2, 3), (1, 2), rowspan=2)
df.Quater.value_counts().plot(kind='bar',alpha= a)
title("Distribution of Bulldozer Sales by Quater")

#add one for prices over time. to show inlation # show frequency of sales per year
#ax4 = plt.subplot2grid((2, 3), (1, 2))
#dfs=df.sort('saledate')
#dfs.set_index('saledate')
#plot_date(dfs.SalePrice,df.saledate)
#title("Sale Price Over Time:")
#plt.xlabel('SalMachineID')
#plt.ylabel('Price ($)')
#plt.xticks(np.arange(0,5))
#plt.yticks(np.arange(0,5))

ax5 = plt.subplot2grid((2, 3), (1, 1))
df.UsageBand.value_counts().plot(kind='bar', alpha=a)
title("Distribution of Hours the Dozers were used. ")


plt.tight_layout()

# %% [markdown]
# # My Regressions:

# %% [markdown]
# Based on chatter in the forums and a basic logical approach to predicting the SalePrice, below is a possible regression from a typical competitor in the competition. Many tried to compensate for the changes in supply and demand of the heavy machinery by including the US Gross Domestic Product as to stand in as a proxy for the changes.
#
# GDP is aggregate of all products produced in the US, so the noise created from producing other goods like a Battleship or a Starbucks latte made GDP a poor proxy for the demand of the products of the Heavy machinery industry. Governmental increased spending and expansionary fiscal policies after the 2008 financial crisis meant that the percentage of public spending to private spending was greater for the majority of the observations and so decreased the explanatory power GDP would have on bulldozer production.
#
# I took a more comprehensive and targeted approach. Because of its position in the heavy machinery industry based on market capitalization and revenue, I included the stock price of the Caterpillar as a proxy for the private expectations of growth for heavy machinery industry. I included an Industrial Production index from the FRED data to directly target the previous quarters output, as the variable was lagged 90 days. And I adjusted for nominal pricing changes between the sale prices of the bulldozers by including a CPI index for the time frame sampled. To further adjust for the seasonality in the supply and demand of the bulldozers I included a Quarter variables that could adjust the sale price for the season the equipment was sold in.

# %% [markdown]
# #### Regression 1:

# %% [markdown]
# This is a possible regression of typical competitor who used a GDP feature to enhance thier model:

# %% [markdown]
# Below are the avaliable features to train our model.

# %%
df.columns
# Out:
# Index([cat_open, cat_high, cat_low, cat_close, cat_vol, cat_adj_close, Industrial_production_index, Infation_Index, GDP, SalesID, SalePrice, MachineID, ModelID_orginal, datasource, auctioneerID, YearMade, MachineHoursCurrentMeter, UsageBand, saledate, fiModelDesc_orginal, fiBaseModel_orginal, fiSecondaryDesc_orginal, fiModelSeries_orginal, fiModelDescriptor_orginal, ProductSize, fiProductClassDesc_orginal, state, ProductGroup_orginal, ProductGroupDesc_orginal, ModelID_machine_appendix, fiModelDesc_machine_appendix, fiBaseModel_machine_appendix, fiSecondaryDesc_machine_appendix, fiModelSeries_machine_appendix, fiModelDescriptor_machine_appendix, fiProductClassDesc_machine_appendix, ProductGroup_machine_appendix, ProductGroupDesc_machine_appendix, MfgYear, fiManufacturerID, fiManufacturerDesc, PrimarySizeBasis, PrimaryLower, PrimaryUpper, Quater, Log_SalePrice], dtype=object)

# %%
formula = 'np.log(SalePrice) ~ C(YearMade) + C(ModelID_machine_appendix) + C(Quater) + C(auctioneerID) + C(UsageBand) + GDP'

# %%
y, x = dmatrices(formula, data=df, return_type='dataframe')# Prepare dataframe for regression
mod = sm.OLS(y, x)   # Describe model, so it can be fitted mod = sm.GLM(y, x, family=sm.families.Gamma()) 
res1 = mod.fit()       # Fit model
results['Typical_competitor_Regression']=[res1, formula] # save results for later
res1.summary()   # Summarize model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      np.log(SalePrice)   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.832
# Method:                 Least Squares   F-statistic:                     53.02
# Date:                Thu, 16 May 2013   Prob (F-statistic):               0.00
# Time:                        14:44:30   Log-Likelihood:                 110.83
# No. Observations:                1368   AIC:                             40.34
# Df Residuals:                    1237   BIC:                             724.3
# Df Model:                         130
# ...
#                                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
plt.figure();
ypred = res1.predict(x)
plt.loglog(x.index, np.exp(ypred), 'bo', x.index, np.exp(y), 'mo', alpha=.25);
plt.grid(color='gray', linestyle='dashed')
plt.title('Typical_competitor_Regression\nOLS prediction, Blue: \nFitted/predicted values: Red');

# %% [markdown]
# #### Regression 2:

# %% [markdown]
# My regression incorporating a more targeted comprehensive approach:

# %%
formula = 'np.log(SalePrice) ~ Infation_Index + Industrial_production_index + np.log(cat_adj_close) + C(YearMade) + C(ModelID_machine_appendix) + C(Quater) + C(auctioneerID) + C(UsageBand)'

# %%
y, x = dmatrices(formula, data=df, return_type='dataframe')
mod = sm.OLS(y, x)   # Describe model, so it can be fitted C(UsageBand)
res2 = mod.fit()     # Fit model
results['My_final_regression']=[res2, formula]
res2.summary()       # Summarize model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      np.log(SalePrice)   R-squared:                       0.889
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     74.84
# Date:                Thu, 16 May 2013   Prob (F-statistic):               0.00
# Time:                        14:44:35   Log-Likelihood:                 325.90
# No. Observations:                1368   AIC:                            -385.8
# Df Residuals:                    1235   BIC:                             308.6
# Df Model:                         132
# ...
#                                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
plt.figure();
ypred = res2.predict(x)
plt.loglog(x.index, np.exp(ypred), 'bo', x.index, np.exp(y), 'mo', alpha=.25);
plt.grid(color='gray', linestyle='dashed')
plt.title('My_final_regression\nOLS prediction, Blue: \nFitted/predicted values: Red');

# %% [markdown]
# #### Regresion 3:

# %% [markdown]
# A varition of the previous regession that exchanges the ModelID feature for fiBaseModel_machine_appendix and fiProductClassDesc_machine_appendix to adjust for possible overfitting.

# %%
df.columns
# Out:
# Index([cat_open, cat_high, cat_low, cat_close, cat_vol, cat_adj_close, Industrial_production_index, Infation_Index, GDP, SalesID, SalePrice, MachineID, ModelID_orginal, datasource, auctioneerID, YearMade, MachineHoursCurrentMeter, UsageBand, saledate, fiModelDesc_orginal, fiBaseModel_orginal, fiSecondaryDesc_orginal, fiModelSeries_orginal, fiModelDescriptor_orginal, ProductSize, fiProductClassDesc_orginal, state, ProductGroup_orginal, ProductGroupDesc_orginal, ModelID_machine_appendix, fiModelDesc_machine_appendix, fiBaseModel_machine_appendix, fiSecondaryDesc_machine_appendix, fiModelSeries_machine_appendix, fiModelDescriptor_machine_appendix, fiProductClassDesc_machine_appendix, ProductGroup_machine_appendix, ProductGroupDesc_machine_appendix, MfgYear, fiManufacturerID, fiManufacturerDesc, PrimarySizeBasis, PrimaryLower, PrimaryUpper, Quater, Log_SalePrice], dtype=object)

# %%
formula = 'np.log(SalePrice) ~ fiBaseModel_machine_appendix + C(fiProductClassDesc_machine_appendix) + Infation_Index + Industrial_production_index + np.log(cat_adj_close) + C(YearMade) + C(Quater) + C(auctioneerID) + C(UsageBand)'

# %%
y, x = dmatrices(formula, data= df, return_type='dataframe')
mod = sm.OLS(y, x)    # Describe model, so it can be fitted  fredb
res3 = mod.fit()      # Fit model
results['My_regression_corrected_for_overfitting']=[res3, formula]
res3.summary()        # Summarize model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      np.log(SalePrice)   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     109.4
# Date:                Thu, 16 May 2013   Prob (F-statistic):               0.00
# Time:                        14:45:47   Log-Likelihood:                 259.04
# No. Observations:                1368   AIC:                            -348.1
# Df Residuals:                    1283   BIC:                             95.71
# Df Model:                          84
# ...
#                                                                                                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ...

# %%
plt.figure();
ypred = res3.predict(x)
plt.loglog(x.index, np.exp(ypred), 'bo', x.index, np.exp(y), 'mo', alpha=.25);
plt.grid(color='gray', linestyle='dashed')
plt.title('My_regression_corrected_for_overfitting\nOLS prediction, Blue: \nFitted/predicted values: Red');

# %% [markdown]
# ### Use our Models to make predictions on the test data:

# %%
test_data = pd.read_csv("Test.csv") # Load in the dataset
test_data = test_data.ix[:,'SalesID':'ProductGroupDesc'] # Remove extraneous Features

# %% [markdown]
# ### Clean data in same way as our training data

# %%
test_data.saledate = test_data.saledate.apply(lambda x: datetime.datetime.strptime(str(x), '%m/%d/%Y %H:%M'))

# %% [markdown]
# ### Merge data on the machine appendix to correct for data quality .

# %%
test_data = pd.merge(test_data, machine_appendix, left_on='MachineID', right_on='MachineID', how='left', suffixes=('_orginal','_machine_appendix'))

# %% [markdown]
# ### Lag our new variales and then merge them to our dataset

# %%
test_data = pd.merge(GDP.shift(90, freq='D'), test_data, left_index=True, right_on='saledate', how='right')
test_data = pd.merge(inflation.shift(90, freq='D'), test_data, left_index=True, right_on='saledate', how='right')
test_data = pd.merge(Industrial_production.shift(90, freq='D'), test_data, left_index=True, right_on='saledate', how='right')
test_data = pd.merge(cat.shift(90, freq='D'), test_data, left_index=True, right_on='saledate', how='right')

# %% [markdown]
# ### Create additional variables necessary for predictions

# %%
test_data['Quater'] = test_data.saledate.apply(agc.quater_maker)
test_data['SalePrice'] = 1.23
test_data = test_data.set_index("SalesID")

# %% [markdown]
# ###Output results and score based on cross validation of our training validation data:

# %% [markdown]
# #### Predict and Output our model:

# %%
for i in results:
    prog = 0 # variable to keep track of the progress of the output.
    check_points = 6 # total number of progress points per iteration.
    model_params = DataFrame(results[i][0].params)
    formula = results[i][1]
    print "\nProcessing: " + i
    prog += 1
    agc.progress(prog, check_points) # a simple textual progress bar
    
    # Create reg friendly test dataframe
    yt, xt = dmatrices(formula, data=test_data, return_type='dataframe')
    prog += 1
    agc.progress(prog, check_points)
    
    # remove extraneous features for efficeny 
    to_drop = list()
    to_drop[:] = [] # Empty list, incase cells are executed out of order
    for c in xt.columns:
        if c not in model_params.index:
            to_drop.append(c)
    xt = xt.drop(to_drop, axis=1)
    
    to_drop[:] = [] # Empty list
    for c in model_params.index : 
        if c not in xt.columns:
            to_drop.append(c)
    model_params = model_params.drop(to_drop)
    prog += 1
    agc.progress(prog, check_points)
    
    # Convert to NumPy arrays for performance
    model_params = np.asarray(model_params)
    yt = np.asarray(yt)
    yt = yt.ravel()
    xt = np.asarray(xt)
    prog += 1
    agc.progress(prog, check_points)
    
    # Use our models to create predictions
    row, col = xt.shape
    model_params = model_params.ravel() # flatten array
    model_array = []
    
    for _ in xrange(row):
            model_array.append(model_params)
    model_array = np.asarray(model_array)
    
    # Multiply matrix together 
    predictions = np.multiply(xt, model_array)
    predictions = np.sum(predictions, axis = 1)
    predictions = np.exp(predictions)    
    prog += 1
    agc.progress(prog, check_points)
    
    # Output Results so our performance on the test set can be scored by Kaggle
    predictions = Series(predictions, name=['SalePrice']) # Put the NumPy array into a Pandas Series for effecient output to Kaggle
    predictions.to_csv(i + ".csv", na_rep=0, float_format='%.3f')
    prog += 1
    agc.progress(prog, check_points)
# Out:
# Processing: My_regression_corrected_for_overfitting
# [#     ]
# [##    ]
# [###   ]
# [####  ]
# [##### ]
# [######]
# Processing: My_final_regression
# [#     ]
# [##    ]
# [###   ]
# [####  ]
# [##### ]
# [######]
# Processing: Typical_competitor_Regression
# [#     ]
# [##    ]
# [###   ]
# [####  ]
# [##### ]
# [######]

# %% [markdown]
# ####Score Our Results:

# %%
# Load in solved Cross Validation dataset for scoring
valid_solution = pd.read_csv('ValidSolution.csv')
valid = pd.read_csv('Valid.csv')
valid['SalePrice'] = np.random.randn() # add the missing independent variable

# %%
for i in results:
    prog = 0 # variable to keep track of the progress of the output.
    check_points = 8 # total number of progress points per iteration.
    model_params = DataFrame(results[i][0].params)
    formula = results[i][1]
    print "\nProcessing: " + i
    prog += 1
    agc.progress(prog, check_points) # a simple textual progress bar
   
    
    yt, xt = dmatrices(formula, data=valid.fillna(value=0), return_type='dataframe') # patsy.incr_dbuilder
    prog += 1
    agc.progress(prog, check_points)

    
    # remove extraneous features for efficeny 
    to_drop[:] = []
    to_drop = list()
    for c in xt.columns:
        if c not in model_params.index:
            to_drop.append(c)
    xt = xt.drop(to_drop, axis=1)
    
    to_drop[:] = [] # Empty list
    for c in model_params.index : 
        if c not in xt.columns:
            to_drop.append(c)
    model_params = model_params.drop(to_drop)
    prog += 1
    agc.progress(prog, check_points)
    
    # Convert to NumPy arrays for performance
    model_params = np.asarray(model_params)
    yt = np.asarray(yt)
    yt = yt.ravel()
    xt = np.asarray(xt)
    prog += 1
    agc.progress(prog, check_points)
    
    # Generate predictions from our training set
    row, col = xt.shape
    model_params = model_params.ravel() # flatten array
    model_array = []
    for _ in xrange(row):
            model_array.append(model_params)
    model_array = np.asarray(model_array)
    prog += 1
    agc.progress(prog, check_points)
   
    # Multiply matrix together 
    predictions = np.multiply(xt, model_array)
    predictions = np.sum(predictions, axis = 1)
    predictions = np.exp(predictions)    
    prog += 1
    agc.progress(prog, check_points)
    
    # Score the results based on our validation set
    actual = np.asarray(valid_solution.SalePrice)
    rmsle = np.sqrt(np.mean(np.power(np.log(actual + 1) - np.log(predictions + 1), 2)))
    prog += 1
    agc.progress(prog, check_points)
    
    rmse = np.sqrt(np.mean(np.power((actual - predictions), 2)))
    prog += 1
    agc.progress(prog, check_points)
    
    print " %s scored an RMSE of : %.4f and an RMSLE of : %.4f\n" %(i, rmse, rmsle)
# Out:
# Processing: My_regression_corrected_for_overfitting
# [#       ]
# [##      ]
# [###     ]
# [####    ]
# [#####   ]
# [######  ]
# [####### ]
# [########]
#  My_regression_corrected_for_overfitting scored an RMSE of : 30108.5141 and an RMSLE of : 0.9567
#
#
# Processing: My_final_regression
# [#       ]
# [##      ]
# [###     ]
# [####    ]
# [#####   ]
# [######  ]
# [####### ]
# [########]
#  My_final_regression scored an RMSE of : 47578.4563 and an RMSLE of : 1.1507
#
#
# Processing: Typical_competitor_Regression
# [#       ]
# [##      ]
# [###     ]
# [####    ]
# [#####   ]
# [######  ]
# [####### ]
# [########]
#  Typical_competitor_Regression scored an RMSE of : 37028.7104 and an RMSLE of : 1.0190

# %% [markdown]
# ### Post Mortem

# %% [markdown]
# My two final models scored on the validation set and on the test set. I selected my final model for submission and finished in 108th place. The winning model conducted by team Leustagos & Titericz scored an RMSLE of 0.22773 using an ensemble of GLM models.
# <br />
# <br />
# What could I have done to improve my own model?
# <br />
# <br />
# If I had used my second model, which corrected for what I believed the over fitting effect of the ModelID variable, I would have scored and placed . But what would I have done to get in the top models? Its as simple as the random forest shown below. It would have had an RMSLE of 0.26704, only 0.039 RMSLE greater than the winning model, and I would have placed 60th if submitted.

# %%
from sklearn.ensemble import RandomForestRegressor
prog = 0 
total_tasks = 7

# Remove duplicates from merge
valid = valid.drop(['fiModelDesc_orginal', 'fiBaseModel_orginal', 'fiSecondaryDesc_orginal', 'fiModelSeries_orginal', 'fiModelDescriptor_orginal', 
            'ProductSize', 'fiProductClassDesc_orginal','ProductGroup_orginal', 'ProductGroupDesc_orginal'], axis=1)
prog += 1
agc.progress(prog, total_tasks)

# Create Random Forest Formula
formula = 'SalePrice ~'
for i, val in enumerate(valid.columns):
    if i != 0 and val != 'SalePrice':
        formula += ' + ' + val 

prog += 1
agc.progress(prog, total_tasks)

# Create friendly dataframe to fit model to 
y, x = dmatrices(formula, data=valid.fillna(value=0), return_type='dataframe')
prog += 1
agc.progress(prog, total_tasks)

# instantiate model
rf = RandomForestRegressor(n_estimators=50, n_jobs=1, compute_importances = True)
prog += 1
agc.progress(prog, total_tasks)

# fit model
rf.fit(x, y)
prog += 1
agc.progress(prog, total_tasks)


# Predict Model
predictions = rf.predict(x)
prog += 1
agc.progress(prog, total_tasks)

# Score the results based on our validation set
actual = np.asarray(valid_solution.SalePrice)
rmsle = np.sqrt(np.mean(np.power(np.log(actual + 1) - np.log(predictions + 1), 2)))
rmse = np.sqrt(np.mean(np.power((actual - predictions), 2)))
print "%s scored an RMSE of : %.4f and an RMSLE of : %.4f\n" %(i, rmse, rmsle)
prog += 1
agc.progress(prog, total_tasks)
# Out:
# [#      ]
# [##     ]
# [###    ]
# [####   ]

# %%
from collections import defaultdict
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import Utils as util

def get_date_dataframe(date_column):
    return pd.DataFrame({
        "SaleYear": [d.year for d in date_column],
        "SaleMonth": [d.month for d in date_column],
        "SaleDay": [d.day for d in date_column]
        }, index=date_column.index)

train, test = util.get_train_test_df()

columns = set(train.columns)
columns.remove("SalesID")
columns.remove("SalePrice")
columns.remove("saledate")

train_fea = get_date_dataframe(train["saledate"])
test_fea = get_date_dataframe(test["saledate"])

for col in columns:
    if train[col].dtype == np.dtype('object'):
        s = np.unique(train[col].fillna(-1).values)
        mapping = pd.Series([x[0] for x in enumerate(s)], index = s)
        train_fea = train_fea.join(train[col].map(mapping).fillna(-1))
        test_fea = test_fea.join(test[col].map(mapping).fillna(-1))
    else:
        train_fea = train_fea.join(train[col].fillna(0))
        test_fea = test_fea.join(test[col].fillna(0))

rf = RandomForestRegressor(n_estimators=50, n_jobs=1, compute_importances = True)
rf.fit(train_fea, train["SalePrice"])
predictions = rf.predict(test_fea)
imp = sorted(zip(train_fea.columns, rf.feature_importances_), key=lambda tup: tup[1], reverse=True)
for fea in imp:
    print(fea)

util.write_submission("random_forest_benchmark.csv", predictions)

# %%
from collections import defaultdict
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
#import util

#def get_date_dataframe(date_column):
#    return pd.DataFrame({
#        "SaleYear": [d.year for d in date_column],
#        "SaleMonth": [d.month for d in date_column],
#        "SaleDay": [d.day for d in date_column]
#        }, index=date_column.index)

train = df 
test = test_data

df["SaleYear"] = df.saledate.apply(lambda x: x.year)
df["SaleMonth"] = df.saledate.apply(lambda x: x.month)
df["SaleDay"]= df.saledate.apply(lambda x: x.year)

columns = set(train.columns)
columns.remove("SalesID")
columns.remove("SalePrice")
columns.remove("saledate")

train_fea = train.set_index("saledate")
test_fea = test.set_index("saledate")

for col in columns:
    if train[col].dtype == np.dtype('object'):
        s = np.unique(train[col].fillna(-1).values)
        mapping = pd.Series([x[0] for x in enumerate(s)], index = s)
        train_fea = train_fea.join(train[col].map(mapping).fillna(-1))
        test_fea = test_fea.join(test[col].map(mapping).fillna(-1))
    else:
        train_fea = train_fea.join(train[col].fillna(0))
        test_fea = test_fea.join(test[col].fillna(0))

rf = RandomForestRegressor(n_estimators=50, n_jobs=1, compute_importances = True)
rf.fit(train_fea, train["SalePrice"])
predictions = rf.predict(test_fea)
imp = sorted(zip(train_fea.columns, rf.feature_importances_), key=lambda tup: tup[1], reverse=True)
for fea in imp:
    print(fea)

predictions.to_csv('Random_Forest.csv')

# %% [markdown]
# ###Version Control

# %%
# %%cmd
# git add BlueBook.ipynb
# git commit

# %%
# !git push origin master

# %%
nsample = 50
sig = 0.25
x1 = np.linspace(0, 20, nsample)
X = np.c_[x1, np.sin(x1), (x1 - 5)**2, np.ones(nsample)]
beta = [0.5, 0.5, -0.02, 5.]
y_true = np.dot(X, beta)
y = y_true + sig * np.random.normal(size=nsample)
olsmod = sm.OLS(y, X)
olsres = olsmod.fit()

print olsres.params
print olsres.bse

ypred = olsres.predict(X)
x1n = np.linspace(20.5, 25, 10)
Xnew = np.c_[x1n, np.sin(x1n), (x1n - 5)**2, np.ones(10)]
ynewpred = olsres.predict(Xnew)  # predict out of sample
print ypred

plt.figure();
plt.plot(x1, y, 'o', x1, y_true, 'b-');
plt.plot(np.hstack((x1, x1n)), np.hstack((ypred, ynewpred)), 'r');
plt.title('OLS prediction, blue: true and data, fitted/predicted values:red');
